# %%
# %run main.py
# Out:
# AppGallery &amp; Games
# RandomForest
# (18, 3)
# (18, 3)
# Accuracy for y2: 0.78
# Accuracy for y3: 0.72
# Accuracy for y4: 0.61
# Accuracy for y2: 0.78
# Accuracy for y2 + y3: 0.75
# Accuracy for y2 + y3 + y4: 0.70
# Predicted Classes for y2: ['Suggestion', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Suggestion', 'Problem/Fault', 'Problem/Fault', 'Suggestion']
# True Classes for y2: ['Suggestion', 'Problem/Fault', 'Suggestion', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Suggestion', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Problem/Fault', 'Suggestion', 'Problem/Fault', 'Suggestion']
# Accuracy for y2: 77.78%
# ...
